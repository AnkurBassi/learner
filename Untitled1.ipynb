# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
#hide
from fastbook import *
from fastai.vision.widgets import *
key = os.environ.get('AZURE_SEARCH_KEY', 'f58cd1186436473d9d82ece3654a6e14')

# %%
??search_images_bing

# %%
result = search_images_bing(key, 'teddy bear')
ims = result.attrgot('content_url')
len(ims)
# Out:
# 150

# %%
??results.attrgot

# %%
for k,c in results[0].items():
    print(k)
    print(c)
    print()
# Out:
# webSearchUrl
# https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&q=grizzly+bear&id=4B18E005DE8D44734820DCB3533255E2AD9FB657&simid=608031189358281798
#
# name
# Bears: Tips From A Controversial Expert | GearJunkie
#
# thumbnailUrl
# https://tse2.mm.bing.net/th?id=OIP.WYa7LLNdotAvnN0wJHsG6gHaGs&pid=Api
#
# datePublished
# 2020-05-21T21:01:00.0000000Z
#
# isFamilyFriendly
# True
#
# contentUrl
# https://images.gearjunkie.com/uploads/2015/07/Grizzly-Bear.jpg
#
# hostPageUrl
# https://gearjunkie.com/bears-safety-tips-bear-spray
#
# contentSize
# 1316280 B
#
# encodingFormat
# jpeg
#
# hostPageDisplayUrl
# https://gearjunkie.com/bears-safety-tips-bear-spray
#
# width
# 2048
#
# height
# 1852
#
# hostPageFavIconUrl
# https://www.bing.com/th?id=ODF.P6c9yQaw10pLnuum6sROaw&pid=Api
#
# hostPageDomainFriendlyName
# GearJunkie
#
# hostPageDiscoveredDate
# 2016-02-04T00:00:00.0000000Z
#
# thumbnail
# {'width': 474, 'height': 428}
#
# imageInsightsToken
# ...

# %%
urls = search_images_ddg('grizzly bear', max_images=100)
len(urls),urls[0]
# Out:
# (100, 'https://upload.wikimedia.org/wikipedia/commons/e/e2/Grizzlybear55.jpg')

# %%
??search_images_ddg

# %%
download_url(urls[0], 'images/bear.jpg')

im = Image.open('images/bear.jpg')
im.thumbnail((256,256))
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=237x256 at 0x7F01EF60E7B8>

# %%
??search_images_ddg

# %%
doc(result.attrgot)

# %%
bear_types = 'grizzly','black','teddy'
path = Path('bears')
meko=('Mehak Bassi','Ankur Bassi','Nirupama Bassi','Dharminder Bassi')

# %%
if not path.exists():
    path.mkdir()
for o in bear_types:
    dest = (path/o)
    dest.mkdir(exist_ok=True)
    results = search_images_bing(key, f'{o} bear')
    download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#470) [Path('bears/black/00000146.jpg'),Path('bears/black/00000106.jpg'),Path('bears/black/00000127.jpg'),Path('bears/black/00000101.jpg'),Path('bears/black/00000027.jpg'),Path('bears/black/00000063.jpg'),Path('bears/black/00000116.jpg'),Path('bears/black/00000079.jpeg'),Path('bears/black/00000128.png'),Path('bears/black/00000051.jpg')...]

# %%
failed = verify_images(fns)
len(failed)
# Out:
# /home/ankur/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/PIL/Image.py:2957: UserWarning: image file could not be identified because WEBP support not installed
#   warnings.warn(message)
# /home/ankur/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/PIL/Image.py:2957: UserWarning: image file could not be identified because WEBP support not installed
#   warnings.warn(message)
# 6

# %%
failed.map(Path.unlink);

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
#doc(DataBlock)

# %%
dls = bears.dataloaders(path,verbose=True)
# Out:
# ...
# Found 464 items
# 2 datasets of sizes 372,92
# Setting up Pipeline: PILBase.create
# Setting up Pipeline: parent_label -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
# Setting up after_item: Pipeline: Resize -- {'size': (128, 128), 'method': 'crop', 'pad_mode': 'reflection', 'resamples': (2, 0), 'p': 1.0} -> ToTensor
# Setting up before_batch: Pipeline:
# Setting up after_batch: Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}

# %%
len(dls.items)
# Out:
# 372

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6548d3b61b5a> in <module>
# ----> 1 bears = bears.new(
#       2     item_tfms=RandomResizedCrop(224, min_scale=0.5),
#       3     batch_tfms=aug_transforms())
#       4 dls = bears.dataloaders(path)
#
# NameError: name 'bears' is not defined

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.179049</td>
#       <td>0.650056</td>
#       <td>0.228261</td>
#       <td>00:40</td>
#     </tr>
#   </tbody>
# </table>
# /home/ankur/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/PIL/Image.py:963: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.188338</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
len(dls.items)
# Out:
# 372

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %%
len(dls.items)
# Out:
# 372

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
#dls.train.show_batch(max_n=64, nrows=16, unique=True)

# %%
len(dls.items)
# Out:
# 372

# %%
bears = bears.new(item_tfms=RandomResizedCrop(224, min_scale=0.5))
dls = bears.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.367893</td>
#       <td>0.308333</td>
#       <td>0.119565</td>
#       <td>00:44</td>
#     </tr>
#   </tbody>
# </table>
# /home/ankur/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/PIL/Image.py:963: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.113367</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.189479</td>
#       <td>0.278670</td>
#       <td>0.108696</td>
#       <td>00:35</td>
#     </tr>
#   </tbody>
# </table>
# /home/ankur/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/PIL/Image.py:963: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.150134</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
path=Path("bears")
bears = bears.new(item_tfms=RandomResizedCrop(224, min_scale=0.5), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
len(dls.items)
#dls.train.show_batch(max_n=64, nrows=16, unique=True)
# Out:
# 372

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.182603</td>
#       <td>0.221872</td>
#       <td>0.086957</td>
#       <td>00:26</td>
#     </tr>
#   </tbody>
# </table>
# /home/ankur/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/PIL/Image.py:963: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.215791</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(tight_layout=True)

# %%
interp.plot_top_losses(5,nrows=1)

# %%
doc(interp.plot_top_losses)

# %%
#hide_output
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# /home/ankur/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/PIL/Image.py:963: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# ...

# %%
path=Path("meko")
if not path.exists():
    path.mkdir()
for o in ['Indian Bridal suits female',]:
    dest = (path/o)
    dest.mkdir(exist_ok=True)
    results = search_images_bing(key, f'{o}')
    download_images(dest, urls=results.attrgot('contentUrl'))

# %%
learn.export(fname="first.pkl")

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#2) [Path('export.pkl'),Path('first.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('bears/grizzly/00000000.jpg')
# Out:
# ('grizzly', tensor(1), tensor([0.0379, 0.9594, 0.0027]))

# %%
learn_inf.dls.vocab
# Out:
# ['black', 'grizzly', 'teddy']

# %%
#hide_output
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
btn_upload = SimpleNamespace(data = ['bears/grizzly/00000000.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
#hide_output
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
pred,pred_idx,probs
# Out:
# ('grizzly', tensor(1), tensor([0.0379, 0.9594, 0.0027]))

# %%
#hide_output
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: grizzly; Probability: 0.9594')

# %%
widgets.Label()
# Out:
# Label(value='')

# %%
f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
# Out:
# 'Prediction: grizzly; Probability: 0.9594'

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
#hide_output
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])

# %%
#hide
#!pip install voila
#!jupyter serverextension enable --sys-prefix voila
